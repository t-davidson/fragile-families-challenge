# %% [markdown]
# Explaining model predictions using LIME.

# %%
import keras
import pickle
import numpy as np
import pandas as pd
import lime
import lime.lime_tabular
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Loading best model. ***Note: Due to the file size this model object is not shared on the Github but I am happy to share it if requested.***

# %%
model = keras.models.load_model('../models/model_4.h5')

# %% [markdown]
# Loading matrix of features for individuals in the validation set. ***Note: This file is not in the repository and I am unable to share it as it contains the challenge data.*** Also loading a list with the names of features (the names of the columns of X_test) that are assumed to be categorical.

# %%
X_test = pickle.load(open('X_test.p', 'rb'))
cat_cols = pickle.load(open('cat_cols.p', 'rb'))

# %% [markdown]
# Now I can use the model and these data to initialize an LIME explainer class.

# %%
names = X_test.columns
explainer = lime.lime_tabular.LimeTabularExplainer(np.array(X_test),
                                                   feature_names=names,
                                                   categorical_features=cat_cols,
                                                   class_names=['r'],
                                                   verbose=True,
                                                   mode='regression')

# %% [markdown]
# Now predicting the GPA for each person and selecting the 50 observations with the lowest and highest predicted values for further inspection using LIME. This should provide an insight into the factors that are associated with different predicted GPA scores.

# %%
y_preds = model.predict(np.array(X_test))

# %%
lowest = np.argsort(y_preds,axis=0)[:50]
highest =  np.argsort(y_preds,axis=0)[::-1][:50]

# %%
obs = [x[0] for x in list(lowest)] + [x[0] for x in list(highest)]

# %%
len(obs)
# Out:
# 100

# %% [markdown]
# In the original script the LIME explanation was done using the sklearn-wrapper around the Keras model. The output format from a standard Keras model object, as used here, is different and does not work with the LIME explainer class. To solve this issue without modifying the source code of either package I used a wrapper function.

# %%
def predict_modified(X):
    """
    This wrapper function takes a numpy array X, predicts values for the 
    array using the keras model specified above, and then converts these 
    predictions from an array of 1-D arrays returned by Keras into a single
    array.
    """
    predicted_vals = model.predict(X) # X is already a numpy array
    return np.array([x[0] for x in predicted_vals[:,]])

# %% [markdown]
# Finally, running the LIME explainer algorithm.

# %%
# %%time
explanation_dict = {}
for i in obs:
    print("Getting explanation for observation ", str(i))
    exp = explainer.explain_instance(np.array(X_test)[i,:], predict_modified, num_features=5)
    explanation_dict[i] = exp.as_list()
# Out:
# Getting explanation for observation  54
# Intercept 2.8573009835
# Prediction_local [ 2.94502686]
# Right: 2.66543
# Getting explanation for observation  226
# Intercept 2.83724764899
# Prediction_local [ 2.94126338]
# Right: 2.66543
# Getting explanation for observation  263
# Intercept 2.87411286381
# Prediction_local [ 2.87604411]
# Right: 2.66543
# Getting explanation for observation  210
# Intercept 2.81560719253
# Prediction_local [ 2.95379783]
# Right: 2.66543
# Getting explanation for observation  30
# Intercept 2.93336423826
# Prediction_local [ 2.93550774]
# Right: 2.66543
# Getting explanation for observation  318
# Intercept 2.82960299242
# Prediction_local [ 2.93116679]
# Right: 2.66543
# Getting explanation for observation  335
# Intercept 2.8116995074
# Prediction_local [ 2.93820374]
# Right: 2.66543
# Getting explanation for observation  162
# Intercept 2.77998123067
# Prediction_local [ 2.92331543]
# Right: 2.66543
# Getting explanation for observation  183
# Intercept 2.70648581351
# Prediction_local [ 2.94359206]
# Right: 2.66543
# Getting explanation for observation  278
# Intercept 2.9225244149
# Prediction_local [ 2.9299259]
# Right: 2.66543
# Getting explanation for observation  294
# Intercept 2.7600328178
# Prediction_local [ 2.94862566]
# Right: 2.66543
# Getting explanation for observation  19
# Intercept 2.87723246591
# Prediction_local [ 2.93272217]
# Right: 2.66543
# Getting explanation for observation  329
# Intercept 2.90330502238
# Prediction_local [ 2.95588422]
# Right: 2.66543
# Getting explanation for observation  256
# Intercept 2.88420647129
# Prediction_local [ 2.93662061]
# Right: 2.66544
# Getting explanation for observation  34
# Intercept 2.9334747439
# Prediction_local [ 2.93281276]
# Right: 2.66544
# Getting explanation for observation  347
# Intercept 2.84898955261
# Prediction_local [ 2.93626307]
# Right: 2.66544
# Getting explanation for observation  212
# Intercept 2.9463454227
# Prediction_local [ 2.91672496]
# Right: 2.66544
# Getting explanation for observation  69
# Intercept 2.74212299899
# Prediction_local [ 2.94809044]
# Right: 2.66544
# Getting explanation for observation  356
# Intercept 2.88566024232
# Prediction_local [ 2.8620779]
# Right: 2.66546
# Getting explanation for observation  224
# Intercept 2.81578671983
# Prediction_local [ 2.93761797]
# Right: 2.66546
# Getting explanation for observation  160
# Intercept 2.82963230084
# Prediction_local [ 2.92721662]
# Right: 2.66546
# Getting explanation for observation  404
# Intercept 2.7140401986
# Prediction_local [ 2.9496482]
# Right: 2.66546
# Getting explanation for observation  311
# Intercept 2.91796765126
# Prediction_local [ 2.92200425]
# Right: 2.66546
# Getting explanation for observation  38
# Intercept 2.72267119542
# Prediction_local [ 2.94026599]
# Right: 2.66547
# Getting explanation for observation  313
# Intercept 2.75557446848
# Prediction_local [ 2.93630309]
# Right: 2.66548
# Getting explanation for observation  423
# Intercept 2.93318006814
# Prediction_local [ 2.94321615]
# Right: 2.6655
# Getting explanation for observation  21
# Intercept 2.83159534254
# Prediction_local [ 2.93913136]
# Right: 2.66551
# Getting explanation for observation  322
# Intercept 2.91462830871
# Prediction_local [ 2.93538044]
# Right: 2.66553
# Getting explanation for observation  114
# Intercept 2.79906485194
# Prediction_local [ 2.92981144]
# Right: 2.66556
# Getting explanation for observation  275
# Intercept 2.91165854467
# Prediction_local [ 2.93313941]
# Right: 2.66563
# Getting explanation for observation  47
# Intercept 2.83212410298
# Prediction_local [ 2.94982759]
# Right: 2.66563
# Getting explanation for observation  397
# Intercept 2.81107343075
# Prediction_local [ 2.83126897]
# Right: 2.66566
# Getting explanation for observation  349
# Intercept 2.83588984405
# Prediction_local [ 2.94518606]
# Right: 2.66566
# Getting explanation for observation  133
# Intercept 2.70327234015
# Prediction_local [ 2.94483934]
# Right: 2.66566
# Getting explanation for observation  128
# Intercept 2.94350621999
# Prediction_local [ 2.93319311]
# Right: 2.66566
# Getting explanation for observation  199
# Intercept 2.75172248169
# Prediction_local [ 2.93048994]
# Right: 2.66567
# Getting explanation for observation  315
# Intercept 2.86454818145
# Prediction_local [ 2.94367146]
# Right: 2.66571
# Getting explanation for observation  299
# Intercept 2.84298116578
# Prediction_local [ 2.93291905]
# Right: 2.66571
# Getting explanation for observation  327
# Intercept 2.84391695284
# Prediction_local [ 2.94458959]
# Right: 2.66571
# Getting explanation for observation  189
# Intercept 2.67151623835
# Prediction_local [ 2.93011279]
# Right: 2.66576
# Getting explanation for observation  119
# Intercept 2.80703276661
# Prediction_local [ 2.93970398]
# Right: 2.66578
# Getting explanation for observation  409
# Intercept 2.83933161121
# Prediction_local [ 2.93748189]
# Right: 2.66579
# Getting explanation for observation  273
# Intercept 2.78968969836
# Prediction_local [ 2.91659307]
# Right: 2.66583
# Getting explanation for observation  211
# Intercept 2.81191242197
# Prediction_local [ 2.93080556]
# Right: 2.66589
# Getting explanation for observation  293
# Intercept 2.92470681521
# Prediction_local [ 2.93464102]
# Right: 2.66596
# Getting explanation for observation  95
# Intercept 2.89292498374
# Prediction_local [ 2.90782159]
# Right: 2.66597
# Getting explanation for observation  51
# Intercept 2.93659499834
# Prediction_local [ 2.91923541]
# Right: 2.66597
# Getting explanation for observation  42
# Intercept 2.7310628459
# Prediction_local [ 2.93678833]
# Right: 2.66598
# Getting explanation for observation  62
# Intercept 2.81873363756
# Prediction_local [ 2.94059754]
# Right: 2.6661
# Getting explanation for observation  168
# Intercept 2.67764614504
# Prediction_local [ 2.93807264]
# Right: 2.66616
# Getting explanation for observation  82
# Intercept 2.85047691674
# Prediction_local [ 2.93386625]
# Right: 3.12243
# Getting explanation for observation  250
# Intercept 2.91145219424
# Prediction_local [ 2.94344305]
# Right: 3.12243
# Getting explanation for observation  245
# Intercept 2.75015389764
# Prediction_local [ 2.94005975]
# Right: 3.12243
# Getting explanation for observation  392
# Intercept 2.70106859911
# Prediction_local [ 2.95326819]
# Right: 3.12243
# Getting explanation for observation  178
# Intercept 2.85227433526
# Prediction_local [ 2.94558175]
# Right: 3.12243
# Getting explanation for observation  94
# Intercept 2.78497842469
# Prediction_local [ 2.94441801]
# Right: 3.12243
# Getting explanation for observation  384
# Intercept 2.76111796552
# Prediction_local [ 2.95005672]
# Right: 3.12243
# Getting explanation for observation  292
# Intercept 2.61601867766
# Prediction_local [ 2.94653904]
# Right: 3.12243
# Getting explanation for observation  320
# Intercept 2.75842192794
# Prediction_local [ 2.95656382]
# Right: 3.12243
# Getting explanation for observation  29
# Intercept 2.9093881663
# Prediction_local [ 2.95846033]
# Right: 3.12243
# Getting explanation for observation  233
# Intercept 2.76316607708
# Prediction_local [ 2.92466468]
# Right: 3.12243
# Getting explanation for observation  364
# Intercept 2.54713657375
# Prediction_local [ 2.94328841]
# Right: 3.12243
# Getting explanation for observation  408
# Intercept 2.83141848537
# Prediction_local [ 2.94130739]
# Right: 3.12243
# Getting explanation for observation  167
# Intercept 2.79150497647
# Prediction_local [ 2.95039553]
# Right: 3.12243
# Getting explanation for observation  357
# Intercept 2.88722208736
# Prediction_local [ 2.9541868]
# Right: 3.12243
# Getting explanation for observation  123
# Intercept 2.94029589188
# Prediction_local [ 2.94786846]
# Right: 3.12243
# Getting explanation for observation  239
# Intercept 2.83674186526
# Prediction_local [ 2.94290227]
# Right: 3.12243
# Getting explanation for observation  375
# Intercept 2.71253972369
# Prediction_local [ 2.94642949]
# Right: 3.12243
# Getting explanation for observation  369
# Intercept 2.83778603488
# Prediction_local [ 2.93115722]
# Right: 3.12243
# Getting explanation for observation  282
# Intercept 2.80676341723
# Prediction_local [ 2.94861446]
# Right: 3.12243
# Getting explanation for observation  382
# Intercept 2.77796149581
# Prediction_local [ 2.94322518]
# Right: 3.12243
# Getting explanation for observation  371
# Intercept 2.87760607699
# Prediction_local [ 2.95050291]
# Right: 3.12243
# Getting explanation for observation  135
# Intercept 2.90189117775
# Prediction_local [ 2.93887928]
# Right: 3.12243
# Getting explanation for observation  118
# Intercept 2.90082773817
# Prediction_local [ 2.93402668]
# Right: 3.12243
# Getting explanation for observation  145
# Intercept 2.78594059009
# Prediction_local [ 2.92412065]
# Right: 3.12243
# Getting explanation for observation  222
# Intercept 2.80513455619
# Prediction_local [ 2.95461015]
# Right: 3.12243
# Getting explanation for observation  204
# Intercept 2.89360397802
# Prediction_local [ 2.94253189]
# Right: 3.12243
# Getting explanation for observation  206
# Intercept 2.82481958216
# Prediction_local [ 2.93839526]
# Right: 3.12243
# Getting explanation for observation  71
# Intercept 2.71276955755
# Prediction_local [ 2.94812957]
# Right: 3.12243
# Getting explanation for observation  28
# Intercept 2.81583233847
# Prediction_local [ 2.94988057]
# Right: 3.12243
# Getting explanation for observation  43
# Intercept 2.77931613439
# Prediction_local [ 2.94626042]
# Right: 3.12243
# Getting explanation for observation  196
# Intercept 2.63822026917
# Prediction_local [ 2.94624098]
# Right: 3.12243
# Getting explanation for observation  15
# Intercept 2.7689413744
# Prediction_local [ 2.94798932]
# Right: 3.12243
# Getting explanation for observation  55
# Intercept 2.78353181562
# Prediction_local [ 2.94466009]
# Right: 3.12243
# Getting explanation for observation  422
# Intercept 2.85555283821
# Prediction_local [ 2.93443671]
# Right: 3.12243
# Getting explanation for observation  417
# Intercept 2.89443426945
# Prediction_local [ 2.94495529]
# Right: 3.12243
# Getting explanation for observation  75
# Intercept 2.76831222782
# Prediction_local [ 2.95441469]
# Right: 3.12243
# Getting explanation for observation  81
# Intercept 2.88967109531
# Prediction_local [ 2.94590273]
# Right: 3.12242
# Getting explanation for observation  383
# Intercept 2.75285916985
# Prediction_local [ 2.93704464]
# Right: 3.12242
# Getting explanation for observation  73
# Intercept 2.90986275037
# Prediction_local [ 2.94671432]
# Right: 3.12242
# Getting explanation for observation  333
# Intercept 2.75122376074
# Prediction_local [ 2.94699573]
# Right: 3.12242
# Getting explanation for observation  86
# Intercept 2.89340895817
# Prediction_local [ 2.92947437]
# Right: 3.12242
# Getting explanation for observation  355
# Intercept 2.82291320971
# Prediction_local [ 2.94479]
# Right: 3.12242
# Getting explanation for observation  380
# Intercept 2.76246970798
# Prediction_local [ 2.95262991]
# Right: 3.12242
# Getting explanation for observation  386
# Intercept 2.81272870274
# Prediction_local [ 2.9505195]
# Right: 3.12236
# Getting explanation for observation  265
# Intercept 2.62335055019
# Prediction_local [ 2.94254219]
# Right: 3.12236
# Getting explanation for observation  412
# Intercept 2.83622024148
# Prediction_local [ 2.94363752]
# Right: 3.12231
# Getting explanation for observation  236
# Intercept 2.68034260935
# Prediction_local [ 2.9487648]
# Right: 3.12224
# Getting explanation for observation  164
# Intercept 2.83432767623
# Prediction_local [ 2.94287486]
# Right: 3.12208
# Getting explanation for observation  155
# Intercept 2.87343789983
# Prediction_local [ 2.94427892]
# Right: 3.12169
# CPU times: user 18h 14min 41s, sys: 6min 47s, total: 18h 21min 29s
# Wall time: 21h 14min 52s

# %%
pickle.dump(explanation_dict, open('new_lime_explanations_dict.p', 'wb'))

# %%
explanation_dict
# Out:
# {15: [('m3j4b_6_1.0 <= 0.00', 0.082601255055925388),
#   ('f3d3a_5_1.0 <= 0.00', 0.062078020834230613),
#   ('m4d4_4.0 <= 0.00', 0.014356585195862134),
#   ('p5j10a_3.0 <= 0.00', 0.010538206245675492),
#   ('m4h1l_2.0 <= 0.00', 0.0094738829952781805)],
#  19: [('f3i2_9.0 <= 0.00', 0.029054045455762831),
#   ('t5b3e_3.0 <= 0.00', 0.028583245177947875),
#   ('hv3f5_6.0 <= 0.00', 0.014999446000797939),
#   ('f3j2f > 0.33', -0.0094305725743658499),
#   ('0.00 < f5k14f_1.0 <= 1.00', -0.0077164551024945655)],
#  21: [('m2b18g_6.0 <= 0.00', 0.044521990055136927),
#   ('p5i10a_10.0 <= 0.00', 0.033210535574034854),
#   ('m1f15_1.0 <= 0.00', 0.031400485711111009),
#   ('m5a8f03_1.0 > 0.00', -0.010279181353953523),
#   ('f4k10 <= -0.33', 0.0086821913586804921)],
#  28: [('f3d1a_4.0 <= 0.00', 0.070615491440118097),
#   ('p5q2a_3.0 <= 0.00', 0.036323032580108459),
#   ('hv3k1b_5.0 <= 0.00', 0.011213509721147406),
#   ('m2d4a_4.0 <= 0.00', 0.0082278754288294276),
#   ('m4c13_1.0 <= 0.00', 0.0076683240766350852)],
#  29: [('hv3k1a_4.0 <= 0.00', 0.011420965672954645),
#   ('hv4b24_8.0 <= 0.00', 0.010047444770341292),
#   ('0.00 < hv3m21_0.0 <= 1.00', 0.0098192600114255547),
#   ('f3h7_1.0 <= 0.00', 0.0095496688244033952),
#   ('0.00 < hv3g1k_4.0 <= 1.00', 0.0082348211254993)],
#  30: [('p5q3ab_3.0 <= 0.00', 0.026035823341254163),
#   ('m4i7c_1.0 <= 0.00', -0.01413759756972253),
#   ('m3d4b_1.0 <= 0.00', -0.01001291190697582),
#   ('hv3u1_4.0 <= 0.00', 0.0082234671513576087),
#   ('0.00 < m1f15_5.0 <= 1.00', -0.0079652833667075568)],
#  34: [('m5e1q_1.0 <= 0.00', 0.016882694243161956),
#   ('f2j22_4.0 <= 0.00', -0.0099033412226322837),
#   ('-0.76 < m2c2a <= -0.13', -0.0083494092336087993),
#   ('hv3m40a_1.0 <= 0.00', 0.0082578692635568249),
#   ('k5g2h_0.0 <= 0.00', -0.0075497975050900857)],
#  38: [('m3b22_8.0 <= 0.00', 0.1073698451228544),
#   ('m4i13b_1990.0 <= 0.00', 0.067271740874932387),
#   ('hv4ppvtage_70.0 <= 0.00', 0.041656057900114639),
